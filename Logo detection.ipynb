# %% [markdown]
# # Logo detection
# ## Importing fundamental packages

# %%
import os
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import shutil
import random
import seaborn as sns

# %% [markdown]
# ## Number of imag

# %%
train = pd.read_csv('./logo_detection_training.csv')
train.head()
# Out:
#                                photo_filename            logo  confidence  \
# 0  charlotte_1019088214340003257_20150630.jpg            Nike    0.909958
# 1  charlotte_1024020172036248179_20150707.jpg       Starbucks    0.979207
# 2  charlotte_1024309877646020814_20150708.jpg  Hard Rock Cafe    0.979052
# 3  charlotte_1032782615297824087_20150719.jpg          Adidas    0.980238
# 4  charlotte_1037694107574660086_20150726.jpg        Emirates    0.983968
#
#    xsx  xrx  yup  ydw       town
# 0  339  381  394  439  charlotte
# 1  460  751  516  758  charlotte
# 2    0  267  205  364  charlotte
# 3  784  851  546  601  charlotte
# 4   60  304  765  875  charlotte

# %%
noise = pd.read_csv('./logo_detection_noise.csv')
noise.head()
# Out:
#                                photo_filename                            logo  \
# 0  charlotte_1053798563516665358_20150817.jpg        Radio Programas del Perú
# 1  charlotte_1082704794121865973_20150926.jpg  Ultimate Fighting Championship
# 2  charlotte_1084392032404738637_20150929.jpg        Radio Programas del Perú
# 3  charlotte_1106060855881747902_20151028.jpg        Radio Programas del Perú
# 4  charlotte_1106940059913412368_20151030.jpg                New York Yankees
#
#    confidence  xsx   xrx  yup   ydw       town
# 0    0.821678   93   973    0   526  charlotte
# 1    0.991209  336   430  103   147  charlotte
# 2    0.852246   20  1070  143  1020  charlotte
# 3    0.902506  291   661   14   472  charlotte
# 4    0.866926  549   582  154   188  charlotte

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.countplot(x = 'logo', data = train,  ax = ax)
fig = plt.xticks(rotation = 45)

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.countplot(x = 'logo', data = noise,  ax = ax)
fig = plt.xticks(rotation = 45)
